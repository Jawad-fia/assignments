# %%
#total_marks = 500
#math =a
#english=b
#urdu=c
#physics=d
#chemistry=e

total_marks = 500
#math = a
#english=b
#urdu=c
#physics=d
#chemistry=e
a =int(input("Enter marks of the first subject math: "))
if(a>=90):
    print("Grade: pass with A grade")
elif(a>=80&a<90):
    print("Grade: pass with B grade")
elif(a>=70&a<80):
    print("Grade: pass with C grade")
elif(a>=60&a<70):
    print("Grade: pass with D grade")
else:
    print("Grade: Fail scored below 60 marks")
b=int(input("Enter marks of the second subject english: "))
if(b>=90):
    print("Grade: pass with A grade")
elif(b>=80&b<90):
    print("Grade: pass with B grade")
elif(b>=70&b<80):
    print("Grade: pass with C grade")
elif(b>=60&b<70):
    print("Grade: pass with D grade")
else:
    print("Grade: Fail scored below 60 marks")
    
c=int(input("Enter marks of the third urdu: "))
if(c>=90):
    print("Grade: pass with A grade")
elif(c>=80&c<90):
    print("Grade: pass with B grade")
elif(c>=70&c<80):
    print("Grade: pass with C grade")
elif(c>=60&c<70):
    print("Grade: pass with D grade")
else:
    print("Grade: Fail")
d=int(input("Enter marks of the fourth subject physics: "))
if(d>=90):
    print("Grade: pass with A grade")
elif(d>=80&d<90):
    print("Grade: pass with B grade")
elif(d>=70&d<80):
    print("Grade: pass with C grade")
elif(d>=60&d<70):
    print("Grade: pass with D grade")
else:
    print("Grade: Fail")
e=int(input("Enter marks of the fifth subject chemisrty: "))
if(e>=90&e<=100):
    print("Grade: pass with A grade")
elif(e>=80&e<90):
    print("Grade: pass with B grade")
elif(e>=70&e<80):
    print("Grade: pass with C grade")
elif(e>=60&e<70):
    print("Grade: pass with D grade")
else:
    print("Grade: Fail in all papers")
    
obtained_marks= a+b+c+d+e
print(obtained_marks)
avg= obtained_marks / 5
print (avg)
if(avg>=90):
    print("Over all Grade: A")
#elif(avg>=80&avg<90):
 #   print(" Over all Grade: B")
#elif(avg>=70&avg<80):
 #   print("Over all Grade: C")
#elif(avg>=60&avg<70):
 #   print("Over all Grade: D")
#else:
 #   print("Over all Average Grade: F")
# Out:
# Enter marks of the first subject math: 92
# Grade: pass with A grade
# Enter marks of the second subject english: 85
# Grade: pass with B grade
# Enter marks of the third urdu: 75
# Grade: pass with B grade
# Enter marks of the fourth subject physics: 65
# Grade: pass with B grade
# Enter marks of the fifth subject chemisrty: 60
# Grade: pass with A grade
# 377
# 75.4
